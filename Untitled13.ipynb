# %% [markdown]
# <a href="https://colab.research.google.com/github/HAdeelAli11/masar/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Data Cleaning**

# %%
import seaborn as sn
import pandas as pd

#read the data
df = pd.read_csv('/content/shopping_behavior_updated.csv')
diabetes_unc = df

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
df.rename(columns={'Customer ID':'Customer No'}, inplace=True)

# %%
df.sample(5)
# Out:
#       Customer No  Age  Gender Item Purchased     Category  \
# 3318         3319   45  Female         Jacket    Outerwear
# 230           231   66    Male          Scarf  Accessories
# 1103         1104   35    Male         Hoodie     Clothing
# 993           994   51    Male        Sandals     Footwear
# 1561         1562   50    Male          Scarf  Accessories
#
#       Purchase Amount (USD)      Location Size     Color  Season  \
# 3318                     46  North Dakota    M     Olive  Summer
# 230                      88          Utah    L     Olive    Fall
# 1103                     23     Tennessee    S  Charcoal  Spring
# 993                      90          Iowa    M     Peach  Winter
# 1561                     38   Mississippi    M    Indigo  Summer
#
#       Review Rating Subscription Status  Shipping Type Discount Applied  \
# 3318            3.9                  No  Free Shipping               No
# ...

# %%
df.isnull().sum()
# Out:
# Customer No               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#       Customer No  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer No             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
df.nunique()
# Out:
# Customer No               3900
# Age                         53
# Gender                       2
# Item Purchased              25
# Category                     4
# Purchase Amount (USD)       81
# Location                    50
# Size                         4
# Color                       25
# Season                       4
# Review Rating               26
# Subscription Status          2
# Shipping Type                6
# Discount Applied             2
# Promo Code Used              2
# Previous Purchases          50
# Payment Method               6
# Frequency of Purchases       7
# dtype: int64

# %%
df['Size'].unique()
# Out:
# array(['L', 'S', 'M', 'XL'], dtype=object)

# %%
df.Size= df.Size.str.replace('L ', 'L')
df.Size= df.Size.str.replace('S ', 'S')
df.Size= df.Size.str.replace('M ', 'M')
df.Size= df.Size.str.replace('XL ', 'XL')

# %%
location_purchase_info = df.groupby("Location")["Purchase Amount (USD)"].agg(["mean", "median", "sum"])
location_purchase_info.head(10)
# Out:
#                   mean  median   sum
# Location
# Alabama      59.112360    56.0  5261
# Alaska       67.597222    68.5  4867
# Arizona      66.553846    68.0  4326
# Arkansas     61.113924    58.0  4828
# California   59.000000    57.0  5605
# Colorado     56.293333    51.0  4222
# Connecticut  54.179487    48.5  4226
# Delaware     55.325581    52.5  4758
# Florida      55.852941    56.0  3798
# Georgia      58.797468    62.0  4645

# %%
#df.to_csv('HAD_clean_dia.csv')

# %% [markdown]
# ### **Preprocessing**

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler

df = pd.read_csv('/content/HAD_clean_dia.csv')

# %%
df
# Out:
#       Unnamed: 0  Customer No  Age  Gender Item Purchased     Category  \
# 0              0            1   55    Male         Blouse     Clothing
# 1              1            2   19    Male        Sweater     Clothing
# 2              2            3   50    Male          Jeans     Clothing
# 3              3            4   21    Male        Sandals     Footwear
# 4              4            5   45    Male         Blouse     Clothing
# ...          ...          ...  ...     ...            ...          ...
# 3895        3895         3896   40  Female         Hoodie     Clothing
# 3896        3896         3897   52  Female       Backpack  Accessories
# 3897        3897         3898   46  Female           Belt  Accessories
# 3898        3898         3899   44  Female          Shoes     Footwear
# 3899        3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# ...

# %%
del df['Category']

# %%
df.head()
# Out:
#    Unnamed: 0  Customer No  Age Gender Item Purchased  Purchase Amount (USD)  \
# 0           0            1   55   Male         Blouse                     53
# 1           1            2   19   Male        Sweater                     64
# 2           2            3   50   Male          Jeans                     73
# 3           3            4   21   Male        Sandals                     90
# 4           4            5   45   Male         Blouse                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df['Gender'] = df['Gender'].replace({'M': 0})

# %%
df.head()
# Out:
#    Unnamed: 0  Customer No  Age Gender Item Purchased  Purchase Amount (USD)  \
# 0           0            1   55   Male         Blouse                     53
# 1           1            2   19   Male        Sweater                     64
# 2           2            3   50   Male          Jeans                     73
# 3           3            4   21   Male        Sandals                     90
# 4           4            5   45   Male         Blouse                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
shipping_type = df.groupby("Location")["Shipping Type"].value_counts()
shipping_type
# Out:
# Location  Shipping Type
# Alabama   Express           20
#           Store Pickup      19
#           Next Day Air      17
#           2-Day Shipping    16
#           Free Shipping      9
#                             ..
# Wyoming   Express           13
#           Next Day Air      12
#           Standard          11
#           Free Shipping     10
#           2-Day Shipping     8
# Name: Shipping Type, Length: 300, dtype: int64

# %% [markdown]
# ### **Analysis**

# %%
promocode_used = df["Promo Code Used"].value_counts()
promocode_used.plot(kind = "pie", autopct = '%.1f%%', title = "Impact of Promo Code Used on Purchase")
# Out:
# <Axes: title={'center': 'Impact of Promo Code Used on Purchase'}, ylabel='Promo Code Used'>

# %%
shipping = df["Shipping Type"].value_counts()
shipping.plot(kind = "barh", title = "Shipping Method", color = ['blue','yellow','pink','red','orange','lightblue'])
# Out:
# <Axes: title={'center': 'Shipping Method'}>

# %%
Location_count = df["Location"].value_counts()
Location_count.plot(kind = "bar", rot = 90, figsize = (12,4),fontsize = "small", title = "Customer Distribution by Location", ylabel = "Number of Customers")
# Out:
# <Axes: title={'center': 'Customer Distribution by Location'}, ylabel='Number of Customers'>
